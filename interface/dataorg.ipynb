# %%
from TimitInterface import TimitInterface

# %%
dataset = TimitInterface()
# Out:
# 0it [00:00, ?it/s]
# ...
# Map:   0%|          | 0/336 [00:00<?, ? examples/s]

# %%
dataset.data
# Out:
# {'TRAIN/DR4/MMDM0/SI1311': {'phonetic_file': 'c:\\Users\\mzhu2\\BWSI-2024\\cogworks-capstone\\TIMIT\\data\\TRAIN/DR4/MMDM0/SI1311.PHN',
#   'word_file': 'c:\\Users\\mzhu2\\BWSI-2024\\cogworks-capstone\\TIMIT\\data\\TRAIN/DR4/MMDM0/SI1311.WRD',
#   'audio_file': 'c:\\Users\\mzhu2\\BWSI-2024\\cogworks-capstone\\TIMIT\\data\\TRAIN/DR4/MMDM0/SI1311.WAV'},
#  'TRAIN/DR4/MMDM0/SX321': {'phonetic_file': 'c:\\Users\\mzhu2\\BWSI-2024\\cogworks-capstone\\TIMIT\\data\\TRAIN/DR4/MMDM0/SX321.PHN',
#   'word_file': 'c:\\Users\\mzhu2\\BWSI-2024\\cogworks-capstone\\TIMIT\\data\\TRAIN/DR4/MMDM0/SX321.WRD',
#   'audio_file': 'c:\\Users\\mzhu2\\BWSI-2024\\cogworks-capstone\\TIMIT\\data\\TRAIN/DR4/MMDM0/SX321.WAV'},
#  'TRAIN/DR4/MMDM0/SI681': {'audio_file': 'c:\\Users\\mzhu2\\BWSI-2024\\cogworks-capstone\\TIMIT\\data\\TRAIN/DR4/MMDM0/SI681.WAV',
#   'phonetic_file': 'c:\\Users\\mzhu2\\BWSI-2024\\cogworks-capstone\\TIMIT\\data\\TRAIN/DR4/MMDM0/SI681.PHN',
# ...

# %%
dataset.test_dataset
# Out:
# Dataset({
#     features: ['audio', 'text', 'phonetic'],
#     num_rows: 336
# })
